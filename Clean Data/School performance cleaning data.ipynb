# %%
# dependencies
import pandas as pd
import os
import matplotlib
import numpy as np

# %%
# load excel file
# File to Load 
file_to_load = "2017 Grad Rates_4Year.csv"


# Read Purchasing File and store into Pandas data frame
Schools_performance_data = pd.read_csv(file_to_load)
# Schools_performance_data.head()

# %%
# remove all NaN values
Schools_performance_data.dropna(inplace=True)



# replace blank values with zeros
Schools_performance_data.replace('-', 0, inplace = True) 

print(Schools_performance_data.count())
# Out:
# COUNTY_CODE                 4592
# COUNTY_NAME                 4592
# DISTRICT_CODE               4592
# DISTRICT_NAME               4592
# SCHOOL_CODE                 4592
# SCHOOL_NAME                 4592
# SUBGROUP                    4592
# FOUR_YR_GRAD_RATE           4592
# FOUR_YR_ADJ_COHORT_COUNT    4592
# GRADUATED_COUNT             4592
# dtype: int64

# %%
Schools_performance_df=pd.DataFrame(Schools_performance_data)
Schools_performance_df.rename(columns={"COUNTY_CODE": "County Code"},inplace=True)
Schools_performance_df.rename(columns={"COUNTY_NAME": "County Name"},inplace=True)
Schools_performance_df.rename(columns={"DISTRICT_CODE": "District Code"},inplace=True)
Schools_performance_df.rename(columns={"DISTRICT_NAME": "District Name"},inplace=True)
Schools_performance_df.rename(columns={"SCHOOL_CODE": "School Code"},inplace=True)
Schools_performance_df.rename(columns={"SCHOOL_NAME": "School Name"},inplace=True)
Schools_performance_df.rename(columns={"SUBGROUP": "Subgroup"},inplace=True)
Schools_performance_df.rename(columns={"FOUR_YR_GRAD_RATE": "Four Years Graduation Rate"},inplace=True)
Schools_performance_df.rename(columns={"FOUR_YR_ADJ_COHORT_COUNT": "Four Years Adjusted Cohort Count"},inplace=True)
Schools_performance_df.rename(columns={"GRADUATED_COUNT": "Graduated Count"},inplace=True)





Schools_performance_df.head()
# Out:
#    County Code County Name  District Code  District Name  School Code  \
# 0            1    ATLANTIC            110  ATLANTIC CITY           10
# 1            1    ATLANTIC            110  ATLANTIC CITY           10
# 2            1    ATLANTIC            110  ATLANTIC CITY           10
# 3            1    ATLANTIC            110  ATLANTIC CITY           10
# 4            1    ATLANTIC            110  ATLANTIC CITY           10
#
#                  School Name         Subgroup Four Years Graduation Rate  \
# 0  Atlantic City High School            White                      90.00
# 1  Atlantic City High School            Black                      68.71
# 2  Atlantic City High School         Hispanic                      79.44
# 3  Atlantic City High School            Asian                      95.45
# 4  Atlantic City High School  American Indian                          0
#
#   Four Years Adjusted Cohort Count Graduated Count
# 0                               80              72
# 1                              163             112
# 2                              180             143
# 3                               88              84
# 4                                0               0

# %%
# New DF with just schoolwide data
schoolwide_data = Schools_performance_df[Schools_performance_df["Subgroup"] == "Schoolwide"]
schoolwide_data = schoolwide_data.drop(columns = ["County Code", "District Code", "School Code"])
schoolwide_data.head()
# Out:
#    County Name           District Name  \
# 10    ATLANTIC           ATLANTIC CITY
# 32    ATLANTIC  ATLANTIC CO VOCATIONAL
# 54    ATLANTIC          BUENA REGIONAL
# 76    ATLANTIC          EGG HARBOR TWP
# 98    ATLANTIC  GREATER EGG HARBOR REG
#
#                                 School Name    Subgroup  \
# 10                Atlantic City High School  Schoolwide
# 32  Atlantic County Institute of Technology  Schoolwide
# 54               BUENA REGIONAL HIGH SCHOOL  Schoolwide
# 76          EGG HARBOR TOWNSHIP HIGH SCHOOL  Schoolwide
# 98                     Absegami High School  Schoolwide
#
#    Four Years Graduation Rate Four Years Adjusted Cohort Count Graduated Count
# 10                      80.54                              514             414
# 32                      98.74                              318             314
# 54                      86.98                              169             147
# 76                      94.18                              584             550
# 98                      91.83                              355             326

# %%
schoolwide_data = schoolwide_data.astype({"Four Years Adjusted Cohort Count" : int, "Graduated Count" : int})
schoolwide_data.dtypes
# Out:
# County Name                         object
# District Name                       object
# School Name                         object
# Subgroup                            object
# Four Years Graduation Rate          object
# Four Years Adjusted Cohort Count     int32
# Graduated Count                      int32
# dtype: object

# %%
CountyDF = schoolwide_data.groupby(["County Name"]).sum()
CountyDF["Graduation Rate"] = CountyDF["Graduated Count"]/CountyDF["Four Years Adjusted Cohort Count"]
CountyDF.head(10)
# Out:
#              Four Years Adjusted Cohort Count  Graduated Count  \
# County Name
# ATLANTIC                                 9143             8120
# BERGEN                                  24222            22731
# BURLINGTON                              13256            12228
# CAMDEN                                  15726            13515
# CAPE MAY                                 2485             2112
# CHARTERS                                 4452             3951
# CUMBERLAND                               5252             4203
# ESSEX                                   22742            19390
# GLOUCESTER                               9181             8457
# HUDSON                                  16932            14252
#
#              Graduation Rate
# County Name
# ATLANTIC            0.888111
# BERGEN              0.938444
# BURLINGTON          0.922450
# CAMDEN              0.859405
# CAPE MAY            0.849899
# CHARTERS            0.887466
# CUMBERLAND          0.800267
# ESSEX               0.852608
# GLOUCESTER          0.921141
# HUDSON              0.841720

# %%
CountyDF.to_csv("CLEAN_SCHOOL_GRADUATION_DATA.csv")
