# %%
# dependencies
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# File to Load 
file_to_load = "County_Data.csv"


# Read Purchasing File and store into Pandas data frame
county_data = pd.read_csv(file_to_load)

# %%
df_county_data = pd.DataFrame(county_data)
df_county_data
# Out:
#             County Name  Graduation Rate  Poverty Rate  Household Size  \
# 0          ATLANTIC, NJ         0.900643          14.8            2.70
# 1            BERGEN, NJ         0.949646           6.6            2.77
# 2        BURLINGTON, NJ         0.933141           6.3            2.66
# 3                CAMDEN         0.875776          11.5            2.65
# 4              CAPE MAY         0.876754           9.7            2.30
# 5            CUMBERLAND         0.812131          19.2            2.77
# 6                 ESSEX         0.869631          15.8            2.76
# 7            GLOUCESTER         0.933036           6.2            2.74
# 8                HUDSON         0.852759          14.0            2.71
# 9             HUNTERDON         0.964266           3.8            2.63
# 10               MERCER         0.896552          11.7            2.79
# 11            MIDDLESEX         0.904329           8.6            2.84
# 12             MONMOUTH         0.939488           7.2            2.63
# 13               MORRIS         0.947533           4.8            2.71
# 14                OCEAN         0.908800          10.4            2.62
# 15              PASSAIC         0.895948          16.8            2.99
# 16                SALEM         0.873090          15.8            2.47
# 17             SOMERSET         0.942890           5.2            2.88
# 18               SUSSEX         0.948148           4.7            2.62
# 19                UNION         0.883930           9.0            2.93
# 20               WARREN         0.933855           7.2            2.53
# 21        Albany County         0.930000          15.6            2.35
# 22      Allegany County         0.890000          25.9             NaN
# 23         Bronx County         0.710000          42.6            2.84
# 24        Broome County         0.900000          23.5            2.33
# 25   Cattaraugus County         0.880000          25.0            2.31
# 26        Cayuga County         0.880000          15.5            2.37
# 27    Chautauqua County         0.880000          30.1            2.37
# 28       Chemung County         0.900000          22.1            2.50
# 29      Chenango County         0.870000          20.7             NaN
# ..                  ...              ...           ...             ...
# 53        Oneida County         0.880000          26.4            2.46
# 54      Onondaga County         0.910000          21.3            2.39
# 55       Ontario County         0.930000          13.0            2.39
# 56        Orange County         0.890000          20.0            2.91
# 57       Orleans County         0.860000          22.0             NaN
# 58        Oswego County         0.870000          27.3            2.47
# 59        Otsego County         0.910000          17.5             NaN
# 60        Putnam County         0.930000           4.2            2.79
# 61        Queens County         0.810000          19.6            3.03
# 62    Rensselaer County         0.910000          18.8            2.32
# 63      Richmond County         0.890000          17.4            2.85
# 64      Rockland County         0.870000          25.1            3.22
# 65      Saratoga County         0.940000          26.6            2.33
# 66   Schenectady County         0.900000           7.2            3.08
# 67     Schoharie County         0.890000          19.4             NaN
# 68      Schuyler County         0.900000          19.2             NaN
# 69        Seneca County         0.860000          18.3             NaN
# 70  St. Lawrence County         0.880000          14.9            2.39
# 71       Steuben County         0.900000          22.1            2.46
# 72       Suffolk County         0.900000           9.1            3.04
# 73      Sullivan County         0.860000          24.6            2.76
# 74         Tioga County         0.900000          14.3             NaN
# 75      Tompkins County         0.950000          15.5            2.27
# 76        Ulster County         0.900000          14.0            2.44
# 77        Warren County         0.910000          15.5            2.31
# 78    Washington County         0.890000          17.9             NaN
# 79         Wayne County         0.900000          16.3            2.42
# 80   Westchester County         0.880000          11.8            2.72
# 81       Wyoming County         0.880000          16.6             NaN
# 82         Yates County         0.850000          21.1             NaN
#
#     Unemployment Rate  Median Income  Speak a language other than English
# 0                 8.5          61777                                27.50
# 1                 3.9          94107                                40.20
# 2                 5.1          87673                                14.70
# 3                 6.4          66196                                20.90
# 4                 7.1          66953                                 9.70
# 5                10.1          52627                                27.30
# 6                 7.7          60430                                37.90
# 7                 5.9          86496                                 8.50
# 8                 4.5          67154                                58.70
# 9                 3.7         112038                                11.60
# 10                5.6          79173                                30.10
# 11                4.8          85337                                44.20
# 12                5.0          98270                                17.70
# 13                3.7         114732                                25.20
# 14                5.2          71081                                13.50
# 15                4.8          64233                                50.20
# 16                5.9          61250                                 8.46
# 17                3.9         112153                                30.20
# 18                5.3          90026                                 9.70
# 19                5.8          77326                                43.70
# 20                5.1          80657                                11.50
# 21                4.7          60904                                13.80
# 22                NaN          44085                                  NaN
# 23               10.9          35302                                60.00
# 24                7.1          47744                                 8.70
# 25                5.5          43884                                 4.60
# 26                4.2          53114                                  NaN
# 27                5.9          43211                                  NaN
# 28                6.0          49578                                  NaN
# 29                NaN          46979                                  NaN
# ..                ...            ...                                  ...
# 53                4.5          49838                                13.60
# 54                6.0          55717                                10.80
# 55                3.3          58070                                  NaN
# 56                4.5          71910                                24.40
# 57                NaN          48731                                  NaN
# 58                7.3          49571                                  NaN
# 59                NaN          49689                                  NaN
# 60                5.1          97606                                19.30
# 61                5.2          59758                                55.70
# 62                5.0          61754                                 7.80
# 63                4.3          74021                                34.30
# 64                4.6          86134                                38.80
# 65                3.0          46313                                 7.30
# 66               10.3          74080                                 9.40
# 67                NaN          59959                                  NaN
# 68                NaN          50607                                  NaN
# 69                NaN          47229                                  NaN
# 70                6.6          50073                                 8.70
# 71                5.7          48823                                  NaN
# 72                4.0          90128                                22.90
# 73               10.4          52027                                  NaN
# 74                NaN          58115                                  NaN
# 75                3.3          54133                                  NaN
# 76                5.3          60393                                11.20
# 77                4.4          57174                                  NaN
# 78                NaN          51449                                  NaN
# 79                4.6          51627                                  NaN
# 80                5.1          86226                                34.50
# 81                NaN          53612                                  NaN
# 82                NaN          50105                                  NaN
#
# [83 rows x 7 columns]

# %%
#Setup Axis
county = df_county_data["County Name"]
grad_rate = df_county_data["Graduation Rate"]
x_axis = np.arange(len(grad_rate))

# Create a bar chart based upon the above data
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, county, rotation= 90)
plt.bar(x_axis, grad_rate, color="b", align="center")
plt.title("County Graduation Rates")
plt.xlabel("Counties")
plt.ylabel("Graduation Rates")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Graduation_Rates.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Povery

# %%
county = df_county_data["County Name"]
pov_rate = df_county_data["Poverty Rate"]
x_axis = np.arange(len(pov_rate))
# Create a bar chart based upon the above data
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, county, rotation= 90)
plt.bar(x_axis, pov_rate, color="r", align="center")
plt.title("County Poverty Rates")
plt.xlabel("Counties")
plt.ylabel("Poverty Rates")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Poverty_Rates.png", bbox_inches = "tight")
plt.show()

# %%
grad_rate = df_county_data["Graduation Rate"]
pov_rate = df_county_data["Poverty Rate"]

plt.scatter(pov_rate, grad_rate)

plt.grid()
plt.title("NJ High School Graduation Rates and Poverty Rates by County")
plt.ylabel("Graduation Rates")
plt.xlabel("Poverty Rate")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Grad_Poverty_Rates1.png", bbox_inches = "tight")
plt.show()

# %%
fig, ax1 = plt.subplots()

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, county, rotation= 90)

grad_rate = df_county_data["Graduation Rate"]
county = df_county_data["County Name"]
pov_rate = df_county_data["Poverty Rate"]
t = np.arange(len(county))
ax1.plot(t, pov_rate, 'b-')
ax1.set_xlabel('county')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('poverty rate', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()

ax2.plot(t,grad_rate, 'r*')
ax2.set_ylabel('Graduation Rate', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.savefig("Images/County_Grad_Poverty_Rates2.png", bbox_inches = "tight")
plt.show()

# %%
fig = plt.figure(figsize=(8,6)) 
x = df_county_data["Poverty Rate"] 
y = df_county_data["Graduation Rate"] 
plt.scatter(x, y, color="g", marker="o", alpha=0.9) 

#Calculate and add R2 value
mask = ~np.isnan(x) & ~np.isnan(y)


#Add regression line
sns.regplot(df_county_data["Poverty Rate"], 
              df_county_data["Graduation Rate"], color='r',label = "Poverty " )

# Incorporate the other graph properties
plt.title("Correlation between Graduation rates and Poverty rates")
plt.ylabel("Graduation rate")
plt.xlabel("Poverty rate") 

plt.legend(loc='best')
plt.grid(True)
sns.set_style('whitegrid')
plt.text(21, 0.925, "Note:\nWe notice an inverse corellation ship between Graduation rates and Povetry rates.")

plt.savefig("Images/County_Grad_Poverty_Rates3.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Household Size

# %%
county = df_county_data["County Name"]
house_size = df_county_data["Household Size"]
x_axis = np.arange(len(house_size))
# Create a bar chart based upon the above data
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, county, rotation= 90)
plt.bar(x_axis, house_size, color="r", align="center")
plt.title("County Household Size")
plt.xlabel("Counties")
plt.ylabel("Household Size")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Household_Size.png", bbox_inches = "tight")
plt.show()

# %%
grad_rate = df_county_data["Graduation Rate"]
house_size = df_county_data["Household Size"]

plt.scatter(house_size, grad_rate)

plt.grid()
plt.title("High School Graduation Rates and Household Size by County")
plt.ylabel("Graduation Rates")
plt.xlabel("Household Size")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Grad_House_Rates.png", bbox_inches = "tight")
plt.show()

# %%
fig, ax1 = plt.subplots()

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, county, rotation= 90)

grad_rate = df_county_data["Graduation Rate"]
county = df_county_data["County Name"]
pov_rate = df_county_data["Household Size"]
t = np.arange(len(county))
ax1.plot(t, pov_rate, 'b-')
ax1.set_xlabel('county')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('HouseHold Size', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()

ax2.plot(t,grad_rate, 'r*')
ax2.set_ylabel('Graduation Rate', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.savefig("Images/County_Grad_House_Rates1.png", bbox_inches = "tight")
plt.show()

# %%
fig = plt.figure(figsize=(8,6)) 
x = df_county_data["Household Size"]
y = df_county_data["Graduation Rate"] 
plt.scatter(x, y, color="g", marker="o", alpha=0.9) 

#Calculate and add R2 value
mask = ~np.isnan(x) & ~np.isnan(y)


#Add regression line
sns.regplot(df_county_data["Household Size"], 
              df_county_data["Graduation Rate"], color='r',label = "Household Size" )

# Incorporate the other graph properties
plt.title("Correlation between Graduation rates and Household Size")
plt.ylabel("Graduation Rate")
plt.xlabel("House Size") 

plt.legend(loc='best')
plt.grid(True)
sns.set_style('whitegrid')
plt.text(3.5, 0.925, "Note:\nThere is no real correlation shown in this graph.")

plt.savefig("Images/County_Grad_House_Rates2.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Unemployment Rate

# %%
county = df_county_data["County Name"]
house_size = df_county_data["Unemployment Rate"]
x_axis = np.arange(len(house_size))
# Create a bar chart based upon the above data
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, county, rotation= 90)
plt.bar(x_axis, house_size, color="r", align="center")
plt.title("County Unemployment Rate")
plt.xlabel("Counties")
plt.ylabel("Unemployment Rate")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Unemployment1.png", bbox_inches = "tight")
plt.show()

# %%
grad_rate = df_county_data["Graduation Rate"]
house_size = df_county_data["Unemployment Rate"]

plt.scatter(house_size, grad_rate)

plt.grid()
plt.title("High School Graduation Rates and Unemployment Rate by County")
plt.ylabel("Graduation Rates")
plt.xlabel("Unemployment Rate")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Grad_Unemployment_Rates.png", bbox_inches = "tight")
plt.show()

# %%
fig, ax1 = plt.subplots()

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, county, rotation= 90)

grad_rate = df_county_data["Graduation Rate"]
county = df_county_data["County Name"]
pov_rate = df_county_data["Unemployment Rate"]
t = np.arange(len(county))
ax1.plot(t, pov_rate, 'b-')
ax1.set_xlabel('county')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Unemployment Rate', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()

ax2.plot(t,grad_rate, 'r*')
ax2.set_ylabel('Graduation Rate', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.savefig("Images/County_Grad_Unemployment Rate1.png", bbox_inches = "tight")
plt.show()

# %%
fig = plt.figure(figsize=(8,6)) 
x = df_county_data["Unemployment Rate"]
y = df_county_data["Graduation Rate"] 
plt.scatter(x, y, color="g", marker="o", alpha=0.9) 

#Calculate and add R2 value
mask = ~np.isnan(x) & ~np.isnan(y)


#Add regression line
sns.regplot(df_county_data["Unemployment Rate"], 
              df_county_data["Graduation Rate"], color='r',label = "Unemployment Rate" )

# Incorporate the other graph properties
plt.title("Correlation between Graduation Rates and Unemployment Rate")
plt.ylabel("Graduation Rate")
plt.xlabel("Unemployment Rate") 

plt.legend(loc='best')
plt.grid(True)
sns.set_style('whitegrid')
plt.text(12, 0.925, "Note:\nAreas with higher unemployment have a lower graduation rate.")

plt.savefig("Images/County_Grad_Unemployment Rate2.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Median Income

# %%
county = df_county_data["County Name"]
house_size = df_county_data["Median Income"]
x_axis = np.arange(len(house_size))
# Create a bar chart based upon the above data
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, county, rotation= 90)
plt.bar(x_axis, house_size, color="r", align="center")
plt.title("County Median Income")
plt.xlabel("Counties")
plt.ylabel("Unemployment Rate")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Median Income1.png", bbox_inches = "tight")
plt.show()

# %%
grad_rate = df_county_data["Graduation Rate"]
house_size = df_county_data["Median Income"]

plt.scatter(house_size, grad_rate)

plt.grid()
plt.title("High School Graduation Rates and Median Income by County")
plt.ylabel("Graduation Rates")
plt.xlabel("Median Income")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Grad_Median Income1.png", bbox_inches = "tight")
plt.show()

# %%
fig, ax1 = plt.subplots()

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, county, rotation= 90)

grad_rate = df_county_data["Graduation Rate"]
county = df_county_data["County Name"]
pov_rate = df_county_data["Median Income"]
t = np.arange(len(county))
ax1.plot(t, pov_rate, 'b-')
ax1.set_xlabel('county')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Median Income', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()

ax2.plot(t,grad_rate, 'r*')
ax2.set_ylabel('Graduation Rate', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.savefig("Images/County_Grad_Median Income2.png", bbox_inches = "tight")
plt.show()

# %%
fig = plt.figure(figsize=(8,6)) 
x = df_county_data["Median Income"]
y = df_county_data["Graduation Rate"] 
plt.scatter(x, y, color="g", marker="o", alpha=0.9) 

#Calculate and add R2 value
mask = ~np.isnan(x) & ~np.isnan(y)


#Add regression line
sns.regplot(df_county_data["Median Income"], 
              df_county_data["Graduation Rate"], color='r',label = "Median Income" )

# Incorporate the other graph properties
plt.title("Correlation between Graduation rates and Median Income")
plt.ylabel("Graduation rate")
plt.xlabel("Median Income") 

plt.legend(loc='best')
plt.grid(True)
sns.set_style('whitegrid')
plt.text(120000, 0.925, "Note:\nAreas with higher median income have a higher graduation rate.")

plt.savefig("Images/County_Grad_Median Income3.png", bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Speak a language other than English

# %%
county = df_county_data["County Name"]
house_size = df_county_data["Speak a language other than English"]
x_axis = np.arange(len(house_size))
# Create a bar chart based upon the above data
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, county, rotation= 90)
plt.bar(x_axis, house_size, color="r", align="center")
plt.title("County Median Income")
plt.xlabel("Counties")
plt.ylabel("Speak a language other than English")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Speak a language other than English.png", bbox_inches = "tight")
plt.show()

# %%
grad_rate = df_county_data["Graduation Rate"]
house_size = df_county_data["Speak a language other than English"]

plt.scatter(house_size, grad_rate)

plt.grid()
plt.title("High School Graduation Rates and ESL by County")
plt.ylabel("Graduation Rates")
plt.xlabel("Speak a language other than English")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Grad_Speak a language other than English1.png", bbox_inches = "tight")
plt.show()

# %%
fig, ax1 = plt.subplots()

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, county, rotation= 90)

grad_rate = df_county_data["Graduation Rate"]
county = df_county_data["County Name"]
pov_rate = df_county_data["Speak a language other than English"]
t = np.arange(len(county))
ax1.plot(t, pov_rate, 'b-')
ax1.set_xlabel('county')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('Speak a language other than English', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()

ax2.plot(t,grad_rate, 'r*')
ax2.set_ylabel('Graduation Rate', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.savefig("Images/County_Grad_Speak a language other than English2.png", bbox_inches = "tight")
plt.show()

# %%
fig = plt.figure(figsize=(8,6)) 
x = df_county_data["Speak a language other than English"]
y = df_county_data["Graduation Rate"] 
plt.scatter(x, y, color="g", marker="o", alpha=0.9) 

#Calculate and add R2 value
mask = ~np.isnan(x) & ~np.isnan(y)


#Add regression line
sns.regplot(df_county_data["Speak a language other than English"], 
              df_county_data["Graduation Rate"], color='r',label = "Speak a language other than English" )

# Incorporate the other graph properties
plt.title("Correlation between Graduation rates and Median Income")
plt.ylabel("Graduation Rate")
plt.xlabel("Speak a language other than English") 

plt.legend(loc='best')
plt.grid(True)
sns.set_style('whitegrid')
plt.text(65, 0.925, "Note:\nAreas with higher median income have a higher graduation rate.")

plt.savefig("Images/County_Grad_Speak a language other than English3.png", bbox_inches = "tight")
plt.show()
