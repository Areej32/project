# %%
# dependencies
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# load excel file
# File to Load 
file_to_load = "County Grad Rate with Poverty Levels.csv"


# Read Purchasing File and store into Pandas data frame
county_grad_pov = pd.read_csv(file_to_load)

# %%
df_county_grad_pov = pd.DataFrame(county_grad_pov)
df_county_grad_pov
# Out:
#    County Name  Four Years Adjusted Cohort Count  Graduated Count  \
# 0     ATLANTIC                              3422             3082
# 1       BERGEN                             10446             9920
# 2   BURLINGTON                              5549             5178
# 3       CAMDEN                              6118             5358
# 4     CAPE MAY                               998              875
# 5   CUMBERLAND                              1863             1513
# 6        ESSEX                              8614             7491
# 7   GLOUCESTER                              3808             3553
# 8       HUDSON                              5800             4946
# 9    HUNTERDON                              1791             1727
# 10      MERCER                              4669             4186
# 11   MIDDLESEX                              9470             8564
# 12    MONMOUTH                              8081             7592
# ...

# %%
county = df_county_grad_pov["County Name"]
grad_rate = df_county_grad_pov["Graduation Rate"]
x_axis = np.arange(len(grad_rate))

# %%
# Create a bar chart based upon the above data
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, county, rotation= 90)
plt.bar(x_axis, grad_rate, color="b", align="center")
plt.title("County Graduation Rates")
plt.xlabel("Counties")
plt.ylabel("Graduation Rates")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Graduation_Rates.png", bbox_inches = "tight")
plt.show()

# %%
county = df_county_grad_pov["County Name"]
pov_rate = df_county_grad_pov["Poverty Rate"]
x_axis = np.arange(len(pov_rate))
# Create a bar chart based upon the above data
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, county, rotation= 90)
plt.bar(x_axis, pov_rate, color="r", align="center")
plt.title("County Poverty Rates")
plt.xlabel("Counties")
plt.ylabel("Poverty Rates")

# Save an image of the chart and print it to the screen
plt.savefig("Images/County_Poverty_Rates.png", bbox_inches = "tight")
plt.show()

# %%
county = df_county_grad_pov["County Name"]
pov_rate = df_county_grad_pov["Poverty Rate"]
grad_rate = df_county_grad_pov["Graduation Rate"]

width = 0.35       # the width of the bars: can also be len(x) sequence
p1 = plt.bar(tick_locations, pov_rate, width, bottom = pov_rate)
p2 = plt.bar(tick_locations, grad_rate, width)
plt.legend((p1[0], p2[0]), ('Poverty Rates', 'Grad Rates'))

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, county, rotation= 90)

# p1 = plt.bar(tick_locations, pov_rate, width, bottom = pov_rate)
# p2 = plt.bar(tick_locations, grad_rate, width)
#              bottom=pov_rate)

plt.title("County Rates")
plt.xlabel("Counties")
plt.ylabel("Rates")

plt.show()

# %%
fig, ax1 = plt.subplots()

tick_locations = [value for value in x_axis]

plt.xticks(tick_locations, county, rotation= 90)

grad_rate = df_county_grad_pov["Graduation Rate"]
county = df_county_grad_pov["County Name"]
pov_rate = df_county_grad_pov["Poverty Rate"]
t = np.arange(len(county))
ax1.plot(t, pov_rate, 'b-')
ax1.set_xlabel('county')
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_ylabel('poverty rate', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()

ax2.plot(t,grad_rate, 'r*')
ax2.set_ylabel('Graduation Rate', color='r')
ax2.tick_params('y', colors='r')

fig.tight_layout()
plt.show()
plt.savefig("Plot.jpg", bbox_inches = "tight")

# %%
fig = plt.figure(figsize=(8,6)) 
x = df_county_grad_pov["Poverty Rate"] 
y = df_county_grad_pov["Graduation Rate"] 
plt.scatter(x, y, color="g", marker="o", alpha=0.9) 

#Calculate and add R2 value
mask = ~np.isnan(x) & ~np.isnan(y)


#Add regression line
sns.regplot(df_county_grad_pov["Poverty Rate"], 
              df_county_grad_pov["Graduation Rate"], color='r',label = "Poverty " )

# Incorporate the other graph properties
plt.title("Correlation between Graduation rates and Poverty rates")
plt.ylabel("Graduation rate")
plt.xlabel("Poverty rate") 

plt.legend(loc='best')
plt.grid(True)
sns.set_style('whitegrid')
plt.text(21, 0.925, "Note:\nWe notice an inverse corellation ship between Graduation rates and Povetry rates.")


plt.show()

# %%
# Build the scatter plots for each city types
UrbanPlot = plt.scatter(urban_count, urban_avg_fare,
            s = 10*urban_driver_avg,
            c = "coral", 
            edgecolor = "black", linewidths = 1, marker = "o",
            alpha = .8, label = "Urban")

SuburbanPlot = plt.scatter(suburban_count, suburban_avg_fare, 
            s = 10*suburban_driver_avg,
            c = "skyblue",
            edgecolor = "black", linewidths = 1, marker = "o",
            alpha = .8, label = "Suburban")

RuralPlot = plt.scatter(rural_count, rural_avg_fare, 
            s = 10*rural_driver_avg,
            c = "gold", 
            edgecolor = "black", linewidths = 1, marker = "o", 
            alpha = .8, label = "Rural")


# Incorporate the other graph properties
plt.title("Pyber Ride Sharing Data (2016)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)


# Create a legend
lgnd = plt.legend(handles = [UrbanPlot, SuburbanPlot, RuralPlot], loc = "upper right", 
                  title = "City Type", fontsize = "small")
for handle in lgnd.legendHandles:
    handle.set_sizes([25.0])
    
    
# Incorporate a text label regarding circle size
plt.text(45, 35, "Note:\nCircle size correlates with driver count per city.")


# Save Figure
plt.savefig("PyberBubblePlot.jpg", bbox_inches = "tight")


# Show plot
plt.show()
